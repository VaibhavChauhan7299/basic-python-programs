# %%
import numpy as np

x = np.array([1,2,3,4])
print(x)
print(type(x))
# Out:
# [1 2 3 4]
# <class 'numpy.ndarray'>

# %%
y = [1,2,3,4]
print(y)
print(type(y))
# Out:
# [1, 2, 3, 4]
# <class 'list'>

# %%
# %timeit [j**4 for j in range(1,9)]
# Out:
# 276 ns ± 1.11 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %%
import numpy as np

# %timeit np.arange(1,9)**4
# Out:
# 779 ns ± 8.17 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)
